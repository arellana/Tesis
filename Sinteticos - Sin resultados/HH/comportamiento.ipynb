# %%
import numpy as np
import matplotlib.pyplot as plt

import cuentitas
from auxiliares import sigmaVV, sigmaHH

# %%
ep1 = np.linspace(1.4, 8, 100)
ep2 = np.linspace(1.4, 8, 100)
d = np.linspace(0.001, 0.5, 100)
s = np.linspace(0.0004, 0.004, 100)
angulo = np.linspace(0,35*np.pi/180,100)

# %%
# v = sigmaVV(ep1, ep2, 0.3,0.001,0.01, 0.002, 0.01, 20, 0.025)
h = sigmaHH(2, 2.1, 0.3,0.001,0.01, 0.002, 0.01, 20, 0.025)

# %%
h
# Out:
# -16.89353500380835

# %%
plt.plot(ep2,v, label = 'VV')
plt.plot(ep2,h, label = 'HH')
plt.legend()

# %%
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

# the function that I'm going to plot
def z_func(x,y):
    return sigmaHH(x, y, 0.3,0.001,0.01, 0.002, 0.01, 20, 0.025)

#Tengo que evitar siempre que ep1 = ep2, sino explota todo

x = arange(1.4,8,0.01)
y = arange(1.4,8,0.01)
X,Y = meshgrid(x, y) # grid of point
Z = z_func(X, Y) # evaluation of the function on the grid

im = imshow(Z,cmap=cm.RdBu) # drawing the function
# # adding the Contour lines with labels
# cset = contour(Z,arange(-1,1.5,0.2),linewidths=2)#,cmap=cm.Set2)
# clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
# colorbar(im) # adding the colobar on the right
# # latex fashion title
# # title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')
# show()

# %%
# %matplotlib inline
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X,Y,Z)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Z contains NaN values. This may result in rendering artifacts.
#   after removing the cwd from sys.path.
